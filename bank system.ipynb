# %%
#BankAccount():
user_ifor = {"user_name":"" ,"pin":"" ,"balance":60000,"transaction_info":[],}
def register():
       print("n\---register---")
       user_info["username"]=input("enter your username:")
       user_info["pin"]=input("create a password:")
       print("registration successfull")
       
def sign_in():
    user_name=inpit("enter your name:")
    user_password=input("enter your password:")
    if username==user_info["username"] and password==user_info["password"]:
        print("signing has successfully\n")
        return True 
    else:
        print("invalid information, retry again")
        return False
        
def check_balance():
    amount_available=60000
    user_balance[balance]-=amount
    user_balance[balance]+=amount
    input("enter your username:")
    input("enter the account number to get balance:")
    print(f"dear customer your initial balance is{amount}\n")
def sen_money():
    print("n\---send money---")
    print("1.own account")
    print("2.FDH Bank account")
    print("3.mobile wallet")
    choice = input("choose an option (1/3):")

    amount = float(input("enter the amount:"))
    if amount > user_info["balance"]:
        print("you have insulficient balance, check balance first!")
    else:
        user_infor["balance"]-=amount
        user_infor["transaction_info"].append(f"sent MK{amount}")
        print(f"you have successfully sent Mk{amount}.\n")

def cash_withdraw():            
    if choice =="1":
        print("1. generate for self")
        print("2. generate for others")
        option = input("choose an option(1/2):")
        if option in ["1", "2"]:
            input("enter the source account:")
            input("enter platfoam:")
            amount = float(input("enter amount:"))
            comfirm = input("continue? (yes/no):")
            if comfirm.lower() =="yes":
                user_info["balance"] -= amount
                print("withdrawal successful")
            else:
                print("transaction failed.:")
                
def payments():
        print("n---payments---")
        print("1. utility bills")
        print("2. tax payment")
        print("3. water board")
        choice = input("choose an option (1-3):")
        
        amount = float(input("enter amount:"))
        if amount > user_info["balance"]:
            print(" you have insulficient balance")
        else:
            user_info["balance"] -= amount
            user_info["transaction_info"].appen(f"paidMk{amount}")
            print(f"payment of Mk{amount} successfully\n")

def loans():
            print("\n---loans---")
            print("1. loan application")
            print("2. loan repayment")
            print("3. loan calculation")
            if choice =="1":
                input("select loan type:")
                amount =float(input("enter loan amount (Mk:)"))
                print(f"loan of Mk{amount} applied successfully!")

            elif choice =="2":
                amount = float(input("enter loan amount (Mk):"))
                rate = float(input("enter loan rate(%):"))
                duration = int(input("enter the loan pariod(months):"))
                monthly_payments = (amount * (rate / 200) / 12) + (amount / month)
                print(f"estimated monthly payment: Mk{monthly_payment:}\n")

def my_account():
        print("\n---my_account---")
        print("1. balance enquirery")
        print("2. mini statement")
        print("3. interim statement")
        choice == input("choose an option (1-3):")
        if choice =="1":
            input("enter your name")
            input("enter password to access your account")
                
        elif choice =="2":
            print("\n mini statement:")
            for transaction in user_info["transaction_info"][-5:]:
                    print(transaction)
        elif choice == "3":
            input("enter source account:")
            input("select statement format (pdf/csv:)")
            input("enter date range:")
            print("statement generated successfully\n")

def logout():
        print("you are currently logged out.\n")
        return False

def main_menu():
        print("welcome in the online bank system!")
        logged_in = False
        registerd = False
        if not registered:
            print("\n1. register")
            print("2. exit")
            choice = input("enter choice(1/2)")
            if choice =="1":
                registered = True
                name=input("enter your name:")
                number=input("enter your number")
                password=input("enter password to comfirm registering:")
                
            if choice =="2":
                print("exiting the program. bye bye")
                break
            else:
                print("invalid choice")
                
        elif not logged_in:
            print("\n1. sign_in")
            print("2. exit")
            choice = input("enter option(1/2):")
            if choice =="1":
                sign_in=True
                name=input("enter your name:")
                number=input("enter your number:")
                password=input("enter your password to sign in:")
                print("signing in successfully\n")

            elif choice =="2":
                print("exit the system.")
            else:
                print("invalid option.")
                break

        else:
             print("\n---main_menu---")
             print("1. register")
             print("2. sign in")
             print("3. check balance")
             print("4. send money")
             print("5. cash withdraw")
             print("6. payments")
             print("7. loans")
             print("8. exit")
             choice = input("choose option(1-8):")

             if choice =="1":
                send_money()
             elif choice =="2":
                cash_withdraw()
             elif choice =="3":
                payments()
             elif choice =="4":
                loans()
             elif choice =="5":
                my_account()
             elif choice =="6":
                logging_in()
             elif choice =="7":
                logout()
             elif choice =="8":
                print("exiting the programe.")
                    
             else:
                print("invalid choice")
main_menu
